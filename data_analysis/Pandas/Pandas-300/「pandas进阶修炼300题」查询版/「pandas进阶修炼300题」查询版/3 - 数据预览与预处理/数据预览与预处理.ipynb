# %% [markdown]
# # pandas 进阶修炼 ｜早起Python
# <br>
#
# **本习题由公众号【早起Python & 可视化图鉴】 原创，转载及其他形式合作请与我们联系（微信号`sshs321`)，未经授权严禁搬运及二次创作，侵权必究！**
#
#
#
# 本习题基于 `pandas` 版本 `1.1.3`，所有内容应当在 `Jupyter Notebook` 中执行以获得最佳效果。
#
# 不同版本之间写法可能会有少许不同，如若碰到此情况，你应该学会如何自行检索解决。

# %% [markdown]
# # 3 - 数据预览与预处理
# <br>
#
# 在拿到数据第一步当然是对数据做一个大概的浏览，以及对缺失值重复值进行相关处理。
#
# 本小节就将练习这部分的基本操作。
#
# 注意1：为了尽可能多的介绍不同方法，因此本节部分操作不是必须的。
#
# 注意2:当进入到 pandas 操作数据时，很多答案并非唯一也并非最优。

# %% [markdown]
# ## 初始化
#
# <br>
#
# 该 `Notebook` 版本为**习题+答案版**
#
#
# 请执行下方单元格以初始化读取本节习题的答案
#
# 执行完毕后，你可以使用 `ans(1)` 来查看第 1 题的参考解答，其余习题类似。
#
# 注意：所有答案并非固定（唯一），我提供的答案仅供参考（并非推荐答案或者最优解）
#
# 如果发现任何错误或者你有更好的解答，可以微信搜索公众号「早起Python」提交以获得奖励！

# %%
import sys
# sys.path.append('../document/')
# from init import initialize,ans

# res = initialize("../document/answer-3.txt")

# %% [markdown]
# ## 加载数据

# %%
import pandas as pd
df = pd.read_excel("TOP250.xlsx")

# %% [markdown]
# ## 数据查看

# %% [markdown]
# ### 1 - 查看数据维度
#
# 先看看数据多少行，多少列，对接下来的处理量心里有个数

# %%
df.shape
# Out:
# (262, 11)

# %% [markdown]
# ### 2 - 随机查看5条数据

# %%
df.sample(5)
# Out:
#           片名  上映年份   评分       评价人数           导演  \
# 138  爱在日落黄昏时  2004  8.8   415674.0     理查德·林克莱特
# 52       教父2  1974  9.2   424440.0  弗朗西斯·福特·科波拉
# 186     真爱至上  2003  8.6   592095.0      理查德·柯蒂斯
# 235     步履不停  2008  8.8   214565.0         是枝裕和
# 10      星际穿越  2014  9.3  1360671.0     克里斯托弗·诺兰
#
#                                     编剧  \
# 138  理查德·林克莱特 / 朱莉·德尔佩 / 伊桑·霍克 / 金·克里桑
# 52                弗朗西斯·福特·科波拉 / 马里奥·普佐
# 186                            理查德·柯蒂斯
# 235                               是枝裕和
# 10                   乔纳森·诺兰 / 克里斯托弗·诺兰
#
#                                                     主演            类型 国家/地区  \
# 138  伊桑·霍克 / 朱莉·德尔佩 / 弗农·多布切夫 / 路易丝·勒莫瓦纳·托雷斯 / 罗多尔·...       剧情 / 爱情    美国
# 52   阿尔·帕西诺 / 罗伯特·杜瓦尔 / 黛安·基顿 / 罗伯特·德尼罗 / 约翰·凯泽尔 / ...       剧情 / 犯罪    美国
# 186  休·格兰特 / 科林·费尔斯 / 艾玛·汤普森 / 凯拉·奈特莉 / 连姆·尼森 / 托马斯...  剧情 / 喜剧 / 爱情    英国
# 235  阿部宽 / 夏川结衣 / 江原由希子 / 高桥和也 / 田中祥平 / 野本萤 / 林凌雅 /...       剧情 / 家庭    日本
# 10   马修·麦康纳 / 安妮·海瑟薇 / 杰西卡·查斯坦 / 麦肯吉·弗依 / 卡西·阿弗莱克 /...  剧情 / 科幻 / 冒险    美国
#
#       语言  时长(分钟)
# 138  英语     80.0
# 52   英语    202.0
# 186  英语    135.0
# 235   日语   115.0
# 10    英语   169.0

# %% [markdown]
# ### 3 - 查看数据前后5行

# %%
df.head()
# df.tail() # 查看后5行
# Out:
#         片名  上映年份   评分       评价人数        导演                编剧  \
# 0   肖申克的救赎  1994  9.7  2317937.0  弗兰克·德拉邦特  弗兰克·德拉邦特 / 斯蒂芬·金
# 1     霸王别姬  1993  9.6  1720638.0       陈凯歌          芦苇 / 李碧华
# 2     阿甘正传  1994  9.5  1743966.0  罗伯特·泽米吉斯  艾瑞克·罗斯 / 温斯顿·格鲁姆
# 3  这个杀手不太冷  1994  9.4  1922740.0     吕克·贝松             吕克·贝松
# 4    泰坦尼克号  1997  9.4  1706127.0   詹姆斯·卡梅隆           詹姆斯·卡梅隆
#
#                                                   主演            类型 国家/地区  \
# 0  蒂姆·罗宾斯 / 摩根·弗里曼 / 鲍勃·冈顿 / 威廉姆·赛德勒 / 克兰西·布朗 / 吉...       剧情 / 犯罪    美国
# 1  张国荣 / 张丰毅 / 巩俐 / 葛优 / 英达 / 蒋雯丽 / 吴大维 / 吕齐 / 雷汉...  剧情 / 爱情 / 同性    中国
# 2  汤姆·汉克斯 / 罗宾·怀特 / 加里·西尼斯 / 麦凯尔泰·威廉逊 / 莎莉·菲尔德 / ...       剧情 / 爱情    美国
# 3  让·雷诺 / 娜塔莉·波特曼 / 加里·奥德曼 / 丹尼·爱罗 / 彼得·阿佩尔 / 迈克尔...  剧情 / 动作 / 犯罪    法国
# 4  莱昂纳多·迪卡普里奥 / 凯特·温丝莱特 / 比利·赞恩 / 凯西·贝茨 / 弗兰西丝·费舍...  剧情 / 爱情 / 灾难    美国
#
#       语言  时长(分钟)
# 0     英语   142.0
# 1  汉语普通话   171.0
# 2     英语   142.0
# 3    英语    110.0
# 4    英语    194.0

# %% [markdown]
# ### 4 - 查看数据基本信息
#
# 看看数据类型，有无缺失值什么的

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   片名      262 non-null    object
#  1   上映年份    262 non-null    int64
#  2   评分      257 non-null    float64
#  3   评价人数    259 non-null    float64
#  4   导演      262 non-null    object
#  5   编剧      262 non-null    object
#  6   主演      262 non-null    object
#  7   类型      262 non-null    object
#  8   国家/地区   256 non-null    object
#  9   语言      256 non-null    object
#  10  时长(分钟)  256 non-null    float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 22.6+ KB

# %% [markdown]
# ### 5 - 查看数据统计信息｜数值
#
# 查看 **数值型** 列的统计信息，计数、均值什么的

# %%
# df.describe()

df.describe().round(2).T # 一般我会这样用
# Out:
#         count       mean        std       min        25%       50%       75%  \
# 上映年份    262.0    2000.60      15.57    1931.0    1995.00    2004.0    2011.0
# 评分      257.0       8.91       0.26       8.4       8.70       8.9       9.1
# 评价人数    259.0  577631.72  367670.85  106462.0  335307.50  479949.0  693230.5
# 时长(分钟)  256.0     121.83      28.08      45.0     101.75     118.0     136.0
#
#               max
# 上映年份       2019.0
# 评分            9.7
# 评价人数    2317937.0
# 时长(分钟)      237.0

# %% [markdown]
# ### 6 - 查看数据统计信息｜离散
#
# 查看 **离散型** 列的统计信息，计数、频率什么

# %%
df.describe(include=['O']).T
# Out:
#       count unique                                                top freq
# 片名      262    249                                               无人知晓    5
# 导演      262    180                                                宫崎骏    8
# 编剧      262    221                                               是枝裕和    7
# 主演      262    249  柳乐优弥 / 北浦爱 / 木村飞影 / 清水萌萌子 / 韩英惠 / 江原由希子 / 串田和美...    5
# 类型      262    120                                                 剧情   24
# 国家/地区   256     20                                                 美国  111
# 语言      256     26                                                英语    72

# %% [markdown]
# ### 7 - 查看数据统计信息｜整体
#
# 查看 **全部** 列的统计信息

# %%
df.describe(include='all').T
# Out:
#         count unique                                                top freq  \
# 片名        262    249                                               无人知晓    5
# 上映年份    262.0    NaN                                                NaN  NaN
# 评分      257.0    NaN                                                NaN  NaN
# 评价人数    259.0    NaN                                                NaN  NaN
# 导演        262    180                                                宫崎骏    8
# 编剧        262    221                                               是枝裕和    7
# 主演        262    249  柳乐优弥 / 北浦爱 / 木村飞影 / 清水萌萌子 / 韩英惠 / 江原由希子 / 串田和美...    5
# 类型        262    120                                                 剧情   24
# 国家/地区     256     20                                                 美国  111
# 语言        256     26                                                英语    72
# 时长(分钟)  256.0    NaN                                                NaN  NaN
#
#                  mean           std       min       25%       50%       75%  \
# 片名                NaN           NaN       NaN       NaN       NaN       NaN
# 上映年份      2000.599237     15.572709    1931.0    1995.0    2004.0    2011.0
# 评分           8.907782      0.262682       8.4       8.7       8.9       9.1
# 评价人数    577631.718147  367670.85441  106462.0  335307.5  479949.0  693230.5
# 导演                NaN           NaN       NaN       NaN       NaN       NaN
# 编剧                NaN           NaN       NaN       NaN       NaN       NaN
# 主演                NaN           NaN       NaN       NaN       NaN       NaN
# 类型                NaN           NaN       NaN       NaN       NaN       NaN
# 国家/地区             NaN           NaN       NaN       NaN       NaN       NaN
# 语言                NaN           NaN       NaN       NaN       NaN       NaN
# 时长(分钟)     121.828125     28.078073      45.0    101.75     118.0     136.0
#
#               max
# 片名            NaN
# 上映年份       2019.0
# 评分            9.7
# 评价人数    2317937.0
# 导演            NaN
# 编剧            NaN
# 主演            NaN
# 类型            NaN
# 国家/地区         NaN
# 语言            NaN
# 时长(分钟)      237.0

# %% [markdown]
# ## 缺失值处理

# %% [markdown]
# ### 8 - 计算缺失值｜总计

# %% [markdown]
# 通过上面的查看，我们发现部分列是存在缺失值的，那么先看看一共存在多少个缺失值

# %%
df.isna().sum().sum()
# Out:
# 26

# %% [markdown]
# ### 9 - 计算缺失值｜分列
#
# 再看看具体每列有多少缺失值

# %%
df.isnull().sum()
# Out:
# 片名        0
# 上映年份      0
# 评分        5
# 评价人数      3
# 导演        0
# 编剧        0
# 主演        0
# 类型        0
# 国家/地区     6
# 语言        6
# 时长(分钟)    6
# dtype: int64

# %% [markdown]
# ### 10 - 查看缺失值
#
# </br>
#
# 为了后面更方便的处理缺失值，现在先看看全部缺失值所在的行

# %%
# df[df.isna().any(1)]  # 等价与
df[df.isnull().T.any()]
# Out:
#          片名  上映年份   评分       评价人数                       导演  \
# 6      千与千寻  2001  9.4  1822369.0                      宫崎骏
# 12    海上钢琴师  1998  9.3  1371726.0                 朱塞佩·托纳多雷
# 19       熔炉  2011  9.3        NaN                      黄东赫
# 20       教父  1972  9.3   756991.0              弗朗西斯·福特·科波拉
# 21   当幸福来敲门  2006  9.1  1237631.0                加布里埃莱·穆奇诺
# 22       龙猫  1988  9.2  1032307.0                      宫崎骏
# 31     乱世佳人  1939  9.3   556888.0  维克多·弗莱明 / 乔治·库克 / 山姆·伍德
# 43    我不是药神  2018  9.0  1696301.0                      文牧野
# 53      狮子王  1994  9.0   665020.0          罗杰·阿勒斯 / 罗伯·明可夫
# 73       情书  1995  NaN   726751.0                     岩井俊二
# 81     蝴蝶效应  2004  NaN   751155.0       埃里克·布雷斯 / J·麦基·格鲁伯
# 82     心灵捕手  1997  8.9   565379.0                  格斯·范·桑特
# 113    无人知晓  2004  9.1   233881.0                     是枝裕和
# 133     甜蜜蜜  1996  NaN   420172.0                      陈可辛
# 135    萤火之森  2011  8.9        NaN                     大森贵弘
# 139    驯龙高手  2010  8.7   617312.0        迪恩·德布洛斯 / 克里斯·桑德斯
# 166    英雄本色  1986  8.7        NaN                      吴宇森
# 170   谍影重重3  2007  NaN   345352.0                 保罗·格林格拉斯
# 181   头脑特工队  2015  NaN   478719.0      彼特·道格特 / 罗纳尔多·德尔·卡门
# 189    海街日记  2015  8.8   335964.0                     是枝裕和
# 192     惊魂记  1960  9.0   202622.0               阿尔弗雷德·希区柯克
# 193     黑天鹅  2010  8.6   680102.0                达伦·阿伦诺夫斯基
# 197    冰川时代  2002  8.6   507275.0        卡洛斯·沙尔丹哈 / 克里斯·韦奇
# 257      浪潮  2008  8.7   223511.0                  丹尼斯·甘塞尔
#
#                                                     编剧  \
# 6                                                  宫崎骏
# 12                                亚利桑德罗·巴里克 / 朱塞佩·托纳多雷
# 19                                           黄东赫 / 孔枝泳
# 20                                马里奥·普佐 / 弗朗西斯·福特·科波拉
# 21                                             斯蒂夫·康拉德
# 22                                                 宫崎骏
# 31   玛格丽特·米歇尔 / 西德尼·霍华德 / 奥利弗·H·P·加勒特 / 本·赫克特 / 乔·斯...
# 43                                      韩家女 / 钟伟 / 文牧野
# 53                          艾琳·梅琪 / 乔纳森·罗伯特  / 琳达·伍尔芙顿
# 73                                                岩井俊二
# 81                                  J·麦基·格鲁伯 / 埃里克·布雷斯
# 82                                      本·阿弗莱克 / 马特·达蒙
# 113                                               是枝裕和
# 133                                                 岸西
# 135                                                绿川幸
# 139             威廉姆·戴维斯 / 迪恩·德布洛斯 / 克里斯·桑德斯 / 葛蕾熙达·柯维尔
# 166                                    陈庆嘉 / 吴宇森 / 梁淑华
# 170                        托尼·吉尔罗伊 / 乔治·诺非 / 斯科特·Z·本恩斯
# 181  彼特·道格特 / 罗纳尔多·德尔·卡门 / 梅格·勒福夫 / 乔什·库雷 / 迈克尔·阿恩特...
# 189                                        是枝裕和 / 吉田秋生
# 192                                 约瑟夫·斯蒂凡诺 / 罗伯特·布洛克
# 193                      安德雷斯·海因斯 / 马克·海曼 / 约翰·J·麦克劳克林
# 197                       迈克尔·伯格  / 迈克尔·J·威尔森 / 彼得·阿克曼
# 257       丹尼斯·甘塞尔 / 彼得·图万斯 / 约翰尼·道金斯 / 罗恩·比恩巴赫 / 罗恩·琼斯
#
#                                                     主演                 类型  \
# 6    柊瑠美 / 入野自由 / 夏木真理 / 菅原文太 / 中村彰男 / 玉井夕海 / 神木隆之介...       剧情 / 动画 / 奇幻
# 12   蒂姆·罗斯 / 普路特·泰勒·文斯 / 比尔·努恩 / 克兰伦斯·威廉姆斯三世 / 梅兰尼·...            剧情 / 音乐
# 19   孔刘 / 郑有美 / 金贤秀 / 郑仁絮 / 白承焕 / 张光 / 金民尚 / 林贤成 / ...                 剧情
# 20   马龙·白兰度 / 阿尔·帕西诺 / 詹姆斯·肯恩 / 理查德·卡斯特尔诺 / 罗伯特·杜瓦尔...            剧情 / 犯罪
# 21   威尔·史密斯 / 贾登·史密斯 / 坦迪·牛顿 / 布莱恩·豪威  / 詹姆斯·凯伦 / 丹...       剧情 / 家庭 / 传记
# 22   日高法子 / 坂本千夏 / 糸井重里 / 岛本须美 / 北林谷荣 / 高木均 / 雨笠利幸 ...       动画 / 奇幻 / 冒险
# 31   费雯·丽 / 克拉克·盖博 / 奥利维娅·德哈维兰 / 托马斯·米切尔 / 芭芭拉·欧内尔 ...  剧情 / 爱情 / 历史 / 战争
# 43   徐峥 / 王传君 / 周一围 / 谭卓 / 章宇 / 杨新鸣 / 王佳佳 / 王砚辉 / 贾...            剧情 / 喜剧
# 53   乔纳森·泰勒·托马斯 / 马修·布罗德里克 / 杰瑞米·艾恩斯 / 詹姆斯·厄尔·琼斯 / ...       动画 / 歌舞 / 冒险
# 73   中山美穗 / 丰川悦司 / 酒井美纪 / 柏原崇 / 范文雀 / 篠原胜之 / 铃木庆一 /...            剧情 / 爱情
# 81   阿什顿·库彻 / 梅洛拉·沃尔特斯 / 艾米·斯马特 / 埃尔登·汉森 / 威廉姆·李·斯科...  剧情 / 科幻 / 悬疑 / 惊悚
# 82   马特·达蒙 / 罗宾·威廉姆斯 / 本·阿弗莱克 / 斯特兰·斯卡斯加德 / 明妮·德里弗 ...                 剧情
# 113  柳乐优弥 / 北浦爱 / 木村飞影 / 清水萌萌子 / 韩英惠 / 江原由希子 / 串田和美...                 剧情
# 133        黎明 / 张曼玉 / 杨恭如 / 曾志伟 / 杜可风 / 张同祖 / 诸慧荷 / 丁羽            剧情 / 爱情
# 135             佐仓绫音 / 内山昂辉 / 辻亲八 / 山本兼平 / 后藤弘树 / 今井麻美  剧情 / 爱情 / 动画 / 奇幻
# 139  杰伊·巴鲁切尔 / 杰拉德·巴特勒 / 克雷格·费格森 / 亚美莉卡·费雷拉 / 乔纳·希尔...       动画 / 奇幻 / 冒险
# 166  周润发 / 狄龙 / 张国荣 / 朱宝意 / 李子雄 / 田丰 / 吴宇森 / 曾江 / 成...       剧情 / 动作 / 犯罪
# 170  马特·达蒙 / 朱丽娅·斯蒂尔斯 / 大卫·斯特雷泽恩 / 斯科特·格伦 / 帕迪·康斯戴恩...       动作 / 悬疑 / 惊悚
# 181  艾米·波勒 / 菲利丝·史密斯 / 理查德·坎德 / 比尔·哈德尔 / 刘易斯·布莱克 / ...       喜剧 / 动画 / 冒险
# 189  绫濑遥 / 长泽雅美 / 夏帆 / 广濑铃 / 大竹忍 / 堤真一 / 加濑亮 / 风吹淳 ...            剧情 / 家庭
# 192  安东尼·博金斯 / 维拉·迈尔斯 / 约翰·加文 / 珍妮特·利 / 马丁·鲍尔萨姆 / 约...       悬疑 / 惊悚 / 恐怖
# 193  娜塔莉·波特曼 / 米拉·库尼斯 / 文森特·卡索 / 芭芭拉·赫希 / 薇诺娜·瑞德 / ...            剧情 / 惊悚
# 197                  雷·罗马诺 / 约翰·雷吉扎莫 / 丹尼斯·利瑞 / 杰克·布莱克       喜剧 / 动画 / 冒险
# 257  于尔根·福格尔 / 弗雷德里克·劳 / 马克思·雷迈特 / 詹妮弗·乌尔里希 / 克里斯蒂安...            剧情 / 惊悚
#
#     国家/地区      语言  时长(分钟)
# 6      日本      日语     NaN
# 12    意大利     NaN   165.0
# 19     韩国      韩语   125.0
# 20     美国     英语      NaN
# 21     美国     NaN   117.0
# 22     日本      日语     NaN
# 31     美国      英语     NaN
# 43    NaN  汉语普通话      NaN
# 53    NaN     英语     89.0
# 73     日本      日语   117.0
# 81     美国      英语   113.0
# 82     美国     NaN   126.0
# 113    日本      日语     NaN
# 133    中国     粤语    118.0
# 135    日本      日语    45.0
# 139    美国     NaN    98.0
# 166    中国     粤语     95.0
# 170    美国     英语    115.0
# 181    美国     NaN    95.0
# 189   NaN      日语   127.0
# 192   NaN      英语   109.0
# 193    美国     NaN   108.0
# 197   NaN     英语     81.0
# 257   NaN      德语   107.0

# %% [markdown]
# ### 11- 高亮缺失值

# %% [markdown]
# 很明显，虽然上一题找到了全部缺失值所在的行，但是看的很头疼
#
# -> 现在将缺失值进行高亮进一步查看
#
# 指路：<font color = '#E36C07'>**2-15**</font>

# %%
(df[df.isnull().any(1)]
.style
.highlight_null(null_color='yellow'))
# Out:
# <style  type="text/css" >
# #T_29c18_row0_col10,#T_29c18_row1_col9,#T_29c18_row2_col3,#T_29c18_row3_col10,#T_29c18_row4_col9,#T_29c18_row5_col10,#T_29c18_row6_col10,#T_29c18_row7_col8,#T_29c18_row7_col10,#T_29c18_row8_col8,#T_29c18_row9_col2,#T_29c18_row10_col2,#T_29c18_row11_col9,#T_29c18_row12_col10,#T_29c18_row13_col2,#T_29c18_row14_col3,#T_29c18_row15_col9,#T_29c18_row16_col3,#T_29c18_row17_col2,#T_29c18_row18_col2,#T_29c18_row18_col9,#T_29c18_row19_col8,#T_29c18_row20_col8,#T_29c18_row21_col9,#T_29c18_row22_col8,#T_29c18_row23_col8{
#             background-color:  yellow;
#         }</style><table id="T_29c18_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >片名</th>        <th class="col_heading level0 col1" >上映年份</th>        <th class="col_heading level0 col2" >评分</th>        <th class="col_heading level0 col3" >评价人数</th>        <th class="col_heading level0 col4" >导演</th>        <th class="col_heading level0 col5" >编剧</th>        <th class="col_heading level0 col6" >主演</th>        <th class="col_heading level0 col7" >类型</th>        <th class="col_heading level0 col8" >国家/地区</th>        <th class="col_heading level0 col9" >语言</th>        <th class="col_heading level0 col10" >时长(分钟)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_29c18_level0_row0" class="row_heading level0 row0" >6</th>
#                         <td id="T_29c18_row0_col0" class="data row0 col0" >千与千寻</td>
#                         <td id="T_29c18_row0_col1" class="data row0 col1" >2001</td>
#                         <td id="T_29c18_row0_col2" class="data row0 col2" >9.400000</td>
#                         <td id="T_29c18_row0_col3" class="data row0 col3" >1822369.000000</td>
#                         <td id="T_29c18_row0_col4" class="data row0 col4" >宫崎骏</td>
#                         <td id="T_29c18_row0_col5" class="data row0 col5" >宫崎骏</td>
#                         <td id="T_29c18_row0_col6" class="data row0 col6" >柊瑠美 / 入野自由 / 夏木真理 / 菅原文太 / 中村彰男 / 玉井夕海 / 神木隆之介 / 内藤刚志 / 泽口靖子 / 我修院达也 / 大泉洋 / 小林郁夫 / 上条恒彦 / 小野武彦</td>
#                         <td id="T_29c18_row0_col7" class="data row0 col7" >剧情 / 动画 / 奇幻</td>
#                         <td id="T_29c18_row0_col8" class="data row0 col8" >日本</td>
#                         <td id="T_29c18_row0_col9" class="data row0 col9" >日语</td>
#                         <td id="T_29c18_row0_col10" class="data row0 col10" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_29c18_level0_row1" class="row_heading level0 row1" >12</th>
#                         <td id="T_29c18_row1_col0" class="data row1 col0" >海上钢琴师</td>
#                         <td id="T_29c18_row1_col1" class="data row1 col1" >1998</td>
#                         <td id="T_29c18_row1_col2" class="data row1 col2" >9.300000</td>
#                         <td id="T_29c18_row1_col3" class="data row1 col3" >1371726.000000</td>
#                         <td id="T_29c18_row1_col4" class="data row1 col4" >朱塞佩·托纳多雷</td>
#                         <td id="T_29c18_row1_col5" class="data row1 col5" >亚利桑德罗·巴里克 / 朱塞佩·托纳多雷</td>
#                         <td id="T_29c18_row1_col6" class="data row1 col6" >蒂姆·罗斯 / 普路特·泰勒·文斯 / 比尔·努恩 / 克兰伦斯·威廉姆斯三世 / 梅兰尼·蒂埃里 / 皮特·沃恩 / 尼尔·奥布赖恩 / 阿尔贝托·巴斯克斯 / 加布里埃莱·拉维亚 / 科里·巴克 / 西德尼·科尔 / Luigi De Luca / 尼古拉·迪·平托 / 费米·依鲁福祖 / 伊斯顿·盖奇 / 凯文·麦克纳利 / 布莱恩·普林格 / 沙拉·鲁宾 / 希思科特·威廉姆斯 / 阿妮妲·扎格利亚 / 安吉洛·迪洛雷塔</td>
#                         <td id="T_29c18_row1_col7" class="data row1 col7" >剧情 / 音乐</td>
#                         <td id="T_29c18_row1_col8" class="data row1 col8" >意大利</td>
#                         <td id="T_29c18_row1_col9" class="data row1 col9" >nan</td>
#                         <td id="T_29c18_row1_col10" class="data row1 col10" >165.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_29c18_level0_row2" class="row_heading level0 row2" >19</th>
#                         <td id="T_29c18_row2_col0" class="data row2 col0" >熔炉</td>
#                         <td id="T_29c18_row2_col1" class="data row2 col1" >2011</td>
#                         <td id="T_29c18_row2_col2" class="data row2 col2" >9.300000</td>
#                         <td id="T_29c18_row2_col3" class="data row2 col3" >nan</td>
#                         <td id="T_29c18_row2_col4" class="data row2 col4" >黄东赫</td>
#                         <td id="T_29c18_row2_col5" class="data row2 col5" >黄东赫 / 孔枝泳</td>
#                         <td id="T_29c18_row2_col6" class="data row2 col6" >孔刘 / 郑有美 / 金贤秀 / 郑仁絮 / 白承焕 / 张光 / 金民尚 / 林贤成 / 金周灵 / 严孝燮 / 全国焕 / 崔镇浩 / 金志映 / 严智星 / 许在浩 / 张素妍</td>
#                         <td id="T_29c18_row2_col7" class="data row2 col7" >剧情</td>
#                         <td id="T_29c18_row2_col8" class="data row2 col8" >韩国</td>
#                         <td id="T_29c18_row2_col9" class="data row2 col9" >韩语</td>
#                         <td id="T_29c18_row2_col10" class="data row2 col10" >125.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_29c18_level0_row3" class="row_heading level0 row3" >20</th>
#                         <td id="T_29c18_row3_col0" class="data row3 col0" >教父</td>
#                         <td id="T_29c18_row3_col1" class="data row3 col1" >1972</td>
#                         <td id="T_29c18_row3_col2" class="data row3 col2" >9.300000</td>
#                         <td id="T_29c18_row3_col3" class="data row3 col3" >756991.000000</td>
#                         <td id="T_29c18_row3_col4" class="data row3 col4" >弗朗西斯·福特·科波拉</td>
#                         <td id="T_29c18_row3_col5" class="data row3 col5" >马里奥·普佐 / 弗朗西斯·福特·科波拉</td>
#                         <td id="T_29c18_row3_col6" class="data row3 col6" >马龙·白兰度 / 阿尔·帕西诺 / 詹姆斯·肯恩 / 理查德·卡斯特尔诺 / 罗伯特·杜瓦尔 / 斯特林·海登 / 约翰·马利 / 理查德·康特 / 艾尔·勒提埃里 / 黛安·基顿 / 阿贝·维高达 / 塔莉娅·夏尔 / 吉亚尼·罗素 / 约翰·凯泽尔 / 鲁迪·邦德 / 兰尼·蒙大拿</td>
#                         <td id="T_29c18_row3_col7" class="data row3 col7" >剧情 / 犯罪</td>
#                         <td id="T_29c18_row3_col8" class="data row3 col8" >美国</td>
#                         <td id="T_29c18_row3_col9" class="data row3 col9" >英语 </td>
#                         <td id="T_29c18_row3_col10" class="data row3 col10" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_29c18_level0_row4" class="row_heading level0 row4" >21</th>
#                         <td id="T_29c18_row4_col0" class="data row4 col0" >当幸福来敲门</td>
#                         <td id="T_29c18_row4_col1" class="data row4 col1" >2006</td>
#                         <td id="T_29c18_row4_col2" class="data row4 col2" >9.100000</td>
#                         <td id="T_29c18_row4_col3" class="data row4 col3" >1237631.000000</td>
#                         <td id="T_29c18_row4_col4" class="data row4 col4" >加布里埃莱·穆奇诺</td>
#                         <td id="T_29c18_row4_col5" class="data row4 col5" >斯蒂夫·康拉德</td>
#                         <td id="T_29c18_row4_col6" class="data row4 col6" >威尔·史密斯 / 贾登·史密斯 / 坦迪·牛顿 / 布莱恩·豪威  / 詹姆斯·凯伦 / 丹·卡斯泰兰尼塔 / 柯特·富勒 / 塔卡尤·费舍尔 / 凯文·韦斯特 / 乔治·张 / 戴维·迈克尔·西尔弗曼 / 多米尼克·博夫 / 杰弗·卡伦 / 乔伊芙·拉文 / 斯科特·克拉斯</td>
#                         <td id="T_29c18_row4_col7" class="data row4 col7" >剧情 / 家庭 / 传记</td>
#                         <td id="T_29c18_row4_col8" class="data row4 col8" >美国</td>
#                         <td id="T_29c18_row4_col9" class="data row4 col9" >nan</td>
#                         <td id="T_29c18_row4_col10" class="data row4 col10" >117.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_29c18_level0_row5" class="row_heading level0 row5" >22</th>
#                         <td id="T_29c18_row5_col0" class="data row5 col0" >龙猫</td>
#                         <td id="T_29c18_row5_col1" class="data row5 col1" >1988</td>
#                         <td id="T_29c18_row5_col2" class="data row5 col2" >9.200000</td>
#                         <td id="T_29c18_row5_col3" class="data row5 col3" >1032307.000000</td>
#                         <td id="T_29c18_row5_col4" class="data row5 col4" >宫崎骏</td>
#                         <td id="T_29c18_row5

# %% [markdown]
# ### 12 - 删除缺失值
#
# <br>
#
# 处理缺失值最简单的方式，当然是将缺失值出现的行全部删掉～
#
# -> 现在，将缺失值出现的行全部删掉

# %%
# 每一行只要存在缺失值就进行删除
df = df.dropna()

# %% [markdown]
# ### 13 - 缺失值补全｜整体填充
#
# <br>
#
# 除了删除缺失值最省事之外，将全部缺失值替换为一个 **固定的值/文本** 也是一个较为省事的方法'
#
# -> 现在，将全部缺失值替换为 `*`

# %%
df = df.fillna('*')

# %% [markdown]
# ### 14 - 缺失值补全｜向上填充

# %% [markdown]
# 从上一小节的查看数据中，不难发现整理数据是按照评分进行降序排列的
#
# 因此对于评分列的缺失值处理，我们可以用上一个电影的评分进行填充
#
# -> 现在将评分列的缺失值，替换为上一个电影的评分

# %%
df['评分'] = df['评分'].fillna(axis=0,method='ffill')

# %% [markdown]
# ### 15 - 缺失值补全｜整体均值填充

# %% [markdown]
# 对于评价人数列的缺失值处理，我们可以使用整列的均值进行填充
#
# -> 现在，将评价人数列的缺失值，用整列的均值进行填充

# %%
df['评价人数'] = df['评价人数'].fillna(df['评价人数'].mean())

# %% [markdown]
# ### 16 - 缺失值补全｜上下均值填充
#
# <br>
#
# 除了可以使用整列的均值进行填充，也可以使用缺失值位置的上下均值进行填充、
#
# -> 现在，将评价人数列的缺失值，用上下数字的均值进行填充

# %%
df['评价人数'] = df['评价人数'].fillna(df['评价人数'].interpolate())

# %% [markdown]
# ### 17 -缺失值补全｜匹配填充
#
# <br>
#
# 除了利用均值填充，有时还需要根据另一列的值进行匹配填充
#
# -> 现在填充 “语言” 列的缺失值，要求根据 “国家/地区” 列的值进行填充
#
# > 例如 《海上钢琴师》国家/地区为 意大利，根据其他意大利国家对应的语言来看，应填充为 意大利语
#
# **注意：此题会有多种解法**

# %%
df['语言']=df.groupby('国家/地区').语言.bfill()

# %% [markdown]
# ## 重复值处理

# %% [markdown]
# ### 18 - 查找重复值
#
# <br>
#
# 将全部缺失值所在的行筛选出来
#
# **注意：此题会有多种解法**

# %%
# 返回bool类型的数值
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 256    False
# 258    False
# 259    False
# 260    False
# 261    False
# Length: 238, dtype: bool

# %%
df[df.duplicated(keep = False)]
# Out:
#          片名  上映年份   评分      评价人数               导演  \
# 94       超脱  2011  8.9  392204.0            托尼·凯耶
# 99   菊次郎的夏天  1999  8.8  457770.0              北野武
# 100    人生果实  2017  9.5  132229.0             伏原健之
# 101    侧耳倾听  1995  8.9  371774.0             近藤喜文
# 102    无人知晓  2004  9.1  233881.0             是枝裕和
# 103   超能陆战队  2014  8.7  810643.0  唐·霍尔 / 克里斯·威廉姆斯
# 104    倩女幽魂  1987  8.7  591835.0              程小东
# 111    无人知晓  2004  9.1  233881.0             是枝裕和
# 112    无人知晓  2004  9.1  233881.0             是枝裕和
# 116    重庆森林  1994  8.8  639120.0              王家卫
# 117    重庆森林  1994  8.8  639120.0              王家卫
# 119      超脱  2011  8.9  392204.0            托尼·凯耶
# 127  菊次郎的夏天  1999  8.8  457770.0              北野武
# 128    人生果实  2017  9.5  132229.0             伏原健之
# 129    侧耳倾听  1995  8.9  371774.0             近藤喜文
# 130    无人知晓  2004  9.1  233881.0             是枝裕和
# 131   超能陆战队  2014  8.7  810643.0  唐·霍尔 / 克里斯·威廉姆斯
# 132    倩女幽魂  1987  8.7  591835.0              程小东
#
#                                编剧  \
# 94                          卡尔·隆德
# 99                            北野武
# 100            津端修一 / 津端英子 / 树木希林
# 101                      宫崎骏 / 柊葵
# 102                          是枝裕和
# 103  乔丹·罗伯茨 / 丹尼尔·吉尔森 / 罗伯特·L·贝尔德
# 104                           阮继志
# 111                          是枝裕和
# 112                          是枝裕和
# 116                           王家卫
# 117                           王家卫
# 119                         卡尔·隆德
# 127                           北野武
# 128            津端修一 / 津端英子 / 树木希林
# 129                      宫崎骏 / 柊葵
# 130                          是枝裕和
# 131  乔丹·罗伯茨 / 丹尼尔·吉尔森 / 罗伯特·L·贝尔德
# 132                           阮继志
#
#                                                     主演  \
# 94   艾德里安·布洛迪 / 马西娅·盖伊·哈登 / 詹姆斯·肯恩 / 克里斯蒂娜·亨德里克斯 / ...
# 99   北野武 / 关口雄介 / 岸本加世子 / 吉行和子 / 细川典江 / 大家由祐子 / 磨赤儿...
# 100                                                纪录片
# 101  本名阳子 / 小林桂树 / 高山南 / 高桥一生 / 山下容莉枝 / 室井滋 / 露口茂 /...
# 102  柳乐优弥 / 北浦爱 / 木村飞影 / 清水萌萌子 / 韩英惠 / 江原由希子 / 串田和美...
# 103  斯科特·安第斯 / 瑞恩·波特 / 丹尼尔·海尼 / T·J·米勒 / 杰米·钟 / 小达蒙...
# 104         张国荣 / 王祖贤 / 午马 / 刘兆铭 / 林威 / 薛芷伦 / 胡大为 / 王晶
# 111  柳乐优弥 / 北浦爱 / 木村飞影 / 清水萌萌子 / 韩英惠 / 江原由希子 / 串田和美...
# 112  柳乐优弥 / 北浦爱 / 木村飞影 / 清水萌萌子 / 韩英惠 / 江原由希子 / 串田和美...
# 116                         林青霞 / 金城武 / 梁朝伟 / 王菲 / 周嘉玲
# 117                         林青霞 / 金城武 / 梁朝伟 / 王菲 / 周嘉玲
# 119  艾德里安·布洛迪 / 马西娅·盖伊·哈登 / 詹姆斯·肯恩 / 克里斯蒂娜·亨德里克斯 / ...
# 127  北野武 / 关口雄介 / 岸本加世子 / 吉行和子 / 细川典江 / 大家由祐子 / 磨赤儿...
# 128                                                纪录片
# 129  本名阳子 / 小林桂树 / 高山南 / 高桥一生 / 山下容莉枝 / 室井滋 / 露口茂 /...
# 130  柳乐优弥 / 北浦爱 / 木村飞影 / 清水萌萌子 / 韩英惠 / 江原由希子 / 串田和美...
# 131  斯科特·安第斯 / 瑞恩·波特 / 丹尼尔·海尼 / T·J·米勒 / 杰米·钟 / 小达蒙...
# 132         张国荣 / 王祖贤 / 午马 / 刘兆铭 / 林威 / 薛芷伦 / 胡大为 / 王晶
#
#                          类型 国家/地区   语言  时长(分钟)
# 94                       剧情    美国   英语    97.0
# 99                  剧情 / 喜剧    日本   日语   121.0
# 100      life-is-fruity.com    日本   日语    91.0
# 101            剧情 / 爱情 / 动画    日本  日语    111.0
# 102                      剧情    日本   日语   141.0
# 103  喜剧 / 动作 / 科幻 / 动画 / 冒险    美国   英语   102.0
# 104       爱情 / 奇幻 / 武侠 / 古装    中国   粤语    98.0
# 111                      剧情    日本   日语   141.0
# 112                      剧情    日本   日语   141.0
# 116                 剧情 / 爱情    中国  粤语    102.0
# 117                 剧情 / 爱情    中国  粤语    102.0
# 119                      剧情    美国   英语    97.0
# 127                 剧情 / 喜剧    日本   日语   121.0
# 128      life-is-fruity.com    日本   日语    91.0
# 129            剧情 / 爱情 / 动画    日本  日语    111.0
# 130                      剧情    日本   日语   141.0
# 131  喜剧 / 动作 / 科幻 / 动画 / 冒险    美国   英语   102.0
# 132       爱情 / 奇幻 / 武侠 / 古装    中国   粤语    98.0

# %% [markdown]
# ### 19 -查找重复值｜指定
#
# 上面是所有列完全重复的情况，但有时我们只需要根据某列查找缺失值
#
# -> 查找 片名 列全部缺失值
#
# **注意：此题会有多种解法**

# %%
df[df.duplicated(['片名'])]

# 提示 df[df.片名.duplicated()]

# %% [markdown]
# ### 20 - 删除重复值

# %% [markdown]
# 删除全部的重复值

# %%
df = df.drop_duplicates()

# %% [markdown]
# ### 21 - 删除重复值｜指定

# %% [markdown]
# 删除全部的重复值，但保留最后一次出现的值

# %%
df = df.drop_duplicates(keep = 'last')
